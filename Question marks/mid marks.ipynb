# %%
#K.Usha
#2211Cs010277
#Group-4

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("class_marks.csv")

# %%
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %%
df.Total.value_counts()
# Out:
# Total
# 36    7
# 32    6
# 34    5
# 40    5
# 38    5
# 37    4
# 27    4
# 29    4
# 25    4
# 20    4
# 24    4
# 33    4
# 31    3
# 30    3
# 26    3
# 28    3
# 22    3
# 35    3
# 17    2
# 21    2
# 39    2
# 19    1
# 9     1
# 14    1
# 8     1
# 18    1
# 3     1
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (86, 12)

# %%
 df["Q1"] = df["Q1aM4"] + df["Q1bM6"]
 df["Q2"] = df["Q2aM6"] + df["Q2bM4"]
 df["Q3"] = df["Q3aM5"] + df["Q3bM5"]
 df["Q4"] = df["Q4aM3"] + df["Q4bM7"]
 df["Q5"] = df["Q5M10"]
 df["Q6"] = df["Q6aM4"] + df["Q6bM6"]
 df.drop(["Q1aM4", "Q1bM6","Q2aM6","Q2bM4" ,"Q3aM5" , "Q3bM5", "Q4aM3" ,"Q4bM7","Q5M10","Q6aM4","Q6bM6"], axis=1, inplace=True) 
 df
# Out:
#     Total    Q1    Q2    Q3   Q4    Q5    Q6
# 0      37   9.0  10.0   3.0  NaN   8.0  10.0
# 1      32   7.0   7.0   NaN  9.0   9.0   NaN
# 2      33   9.0   6.0  10.0  NaN   8.0   NaN
# 3      24  10.0   9.0   4.0  NaN   NaN   NaN
# 4      36   9.0   8.0   9.0  NaN  10.0   NaN
# ..    ...   ...   ...   ...  ...   ...   ...
# 81     32   9.0   7.0   8.0  NaN   NaN  10.0
# 82     27   4.0   8.0   NaN  NaN   7.0   8.0
# 83     37  10.0   8.0   NaN  NaN   9.0  10.0
# 84     28   NaN   9.0   9.0  NaN   6.0   NaN
# 85     29  10.0   NaN   NaN  8.0   7.0   5.0
#
# [86 rows x 7 columns]

# %%
plt.hist(df['Q5'],color='pink',edgecolor='black',bins=7)
plt.xlabel("Marks scored in Q5")
plt.ylabel("No.of students")
plt.title("Histogram of Q5")
# Out:
# Text(0.5, 1.0, 'Histogram of Q5')

# %% [markdown]
# # majority of students scored 5 marks,with some scoring close to the maximum

# %%
df.plot()
plt.show()

# %%
a1=df.groupby('Q1')['Total']
a1.hist(color="green",grid=False,bins=7)
plt.title('Histogram of students who scored 5-10 Total marks')
plt.xlabel("Total marks obtained")
plt.ylabel("marks in Q2")
plt.show()

# %% [markdown]
# # In Q1 major students got 6 marks

# %%
a2=df.groupby('Q3')['Total']
a2.hist(color="yellow",grid=False,bins=8)
plt.title('Histogram of students who scored 35-40 Total marks')
plt.xlabel("Total marks obtained")
plt.ylabel("marks in Q3")
plt.show()

# %% [markdown]
# # the students who scored 35-40 total marks are got maximum 8 marks in Q3

# %%
df.plot.scatter(x = 'Q2', y = 'Total',color='black',s=30)
plt.title("Scatter Plot for Q1")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q1')

# %% [markdown]
# # scatter plot of marks vs marks in Q2

# %%
df.plot.scatter(x = 'Q3', y = 'Q4',color='purple',s=30)
plt.title("Q3 vs Q4")
plt.xlabel("Q3 scores")
plt.ylabel("Q4 scores")
plt.show()

# %%
 df.boxplot(by='Q3', column =['Total'], grid = False,color='purple')
 plt.title("Boxplot of Q3")
 plt.ylabel("Total")
 plt.show()

# %% [markdown]
# # majoroty of students got 10 marks

# %%
 n=pd.read_csv("class_marks.csv",skiprows=70)
 n
 n['1.2'].plot(kind='pie',figsize=(6,8))
 plt.title("Piechart of marks in Q6")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q6')

# %% [markdown]
# #  The pie chart visually breaks down how marks in Q6 are distributed among students.

# %%
 df.plot.line(x='Q3',y='Total',color='pink')
 plt.title("Line Graph of Q3")
 plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %% [markdown]
# #  The line graph shows how total marks vary with Q3 scores
