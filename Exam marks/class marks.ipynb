# %% [markdown]
#  # mid marks

# %% [markdown]
# K.Usha

# %% [markdown]
# 2211CS010277

# %% [markdown]
# Group-4

# %% [markdown]
# # DESCRIPTION

# %% [markdown]
# data analysis and visualization. It includes sections for,
#
# Data loading and inspection.
#
# Exploratory Data Analysis (EDA), such as summarizing datasets, plotting graphs, and identifying patterns.
#
# Data preprocessing steps, such as handling missing values, scaling, or encoding.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\DELL-PC\Desktop\DA\MIDMARKS-MINOR1.xlsx")

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [718 rows x 8 columns]>

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA') 
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [718 rows x 8 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0     1.0   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1     2.0   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2     3.0   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3     4.0   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4     5.0   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   NaN    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   NaN    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   NaN    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   NaN    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   NaN    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [718 rows x 8 columns]>

# %%
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [718 rows x 8 columns]

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()

# %%
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [716 rows x 8 columns]

# %%
df.shape
# Out:
# (716, 8)

# %%
df.size
# Out:
# 5728

# %%
df=df.replace("A","AB")

# %%
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [716 rows x 8 columns]

# %%
df=df.replace("AB",0)
df=df.replace("MP",-2)

# %%
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [716 rows x 8 columns]

# %%
df.rename(columns={'M-II':'M2'},inplace=True)

# %%
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [716 rows x 8 columns]

# %%
b = df.dropna()

# %%
b
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [716 rows x 8 columns]

# %%
df['S.NO'] = range(1, len(df) + 1)

# %%
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   712    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   713    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   714    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   715    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   716    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [716 rows x 8 columns]

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA') 
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
print("Updated DataFrame with missing sections replaced by 'SIGMA':")
df
# Out:
# Updated DataFrame with missing sections replaced by 'SIGMA':
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   712    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   713    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   714    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# 716   715    ZETA  12.0   1.0   6.0   7.0  15.0  12.0
# 717   716    ZETA  19.0  14.0  17.0  16.0  20.0  19.0
#
# [716 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 716 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     716 non-null    int64
#  1   SECTION  716 non-null    object
#  2   DV       716 non-null    float64
#  3   M2       716 non-null    float64
#  4   PP       716 non-null    float64
#  5   BEEE     716 non-null    float64
#  6   FL       716 non-null    float64
#  7   FIMS     716 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 50.3+ KB

# %%
df['DV'] = pd.to_numeric(df['DV'], errors='coerce')
df['DV'] = df['DV'].fillna(0)
df['DV'] = df['DV'].astype(int)

# %%
df['M2'] = pd.to_numeric(df['M2'], errors='coerce')
df['M2'] = df['M2'].fillna(0)
df['M2'] = df['M2'].astype(int)

# %%
df['PP'] = pd.to_numeric(df['PP'], errors='coerce')
df['PP'] = df['PP'].fillna(0)
df['PP'] = df['PP'].astype(int)

# %%
df['BEEE'] = pd.to_numeric(df['BEEE'], errors='coerce')
df['BEEE'] = df['BEEE'].fillna(0)
df['BEEE'] = df['BEEE'].astype(int)

# %%
df['FL'] = pd.to_numeric(df['FL'], errors='coerce')
df['FL'] = df['FL'].fillna(0)
df['FL'] = df['FL'].astype(int)

# %%
df['FIMS'] = pd.to_numeric(df['FIMS'], errors='coerce')
df['FIMS'] = df['FIMS'].fillna(0)
df['FIMS'] = df['FIMS'].astype(int)

# %%
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS
# 0       1   ALPHA  12   0  17     9  19    15
# 1       2   ALPHA  19  12  16    16  18     3
# 2       3   ALPHA  18  14  18    18  18    16
# 3       4   ALPHA  15   9  19    17  19    15
# 4       5   ALPHA  18  17  19    19  20    18
# ..    ...     ...  ..  ..  ..   ...  ..   ...
# 713   712    ZETA  19   8   8    19  17    18
# 714   713    ZETA  12   1   7    10  20     8
# 715   714    ZETA  17   6  14    14  17    18
# 716   715    ZETA  12   1   6     7  15    12
# 717   716    ZETA  19  14  17    16  20    19
#
# [716 rows x 8 columns]

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()

# %%
df['Total']=df['DV']+df['M2']+df['PP']+df['BEEE']+df['FL']+df['FIMS']

# %%
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total
# 0       1   ALPHA  12   0  17     9  19    15     72
# 1       2   ALPHA  19  12  16    16  18     3     84
# 2       3   ALPHA  18  14  18    18  18    16    102
# 3       4   ALPHA  15   9  19    17  19    15     94
# 4       5   ALPHA  18  17  19    19  20    18    111
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...
# 713   712    ZETA  19   8   8    19  17    18     89
# 714   713    ZETA  12   1   7    10  20     8     58
# 715   714    ZETA  17   6  14    14  17    18     86
# 716   715    ZETA  12   1   6     7  15    12     53
# 717   716    ZETA  19  14  17    16  20    19    105
#
# [716 rows x 9 columns]

# %%
df['Percentage']=round((df['Total']/120)*100,2)

# %%
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...
# 713   712    ZETA  19   8   8    19  17    18     89       74.17
# 714   713    ZETA  12   1   7    10  20     8     58       48.33
# 715   714    ZETA  17   6  14    14  17    18     86       71.67
# 716   715    ZETA  12   1   6     7  15    12     53       44.17
# 717   716    ZETA  19  14  17    16  20    19    105       87.50
#
# [716 rows x 10 columns]

# %%
df.loc[df["Total"]>110,["Grade"]]="A+"
df.loc[(df["Total"]>90) & (df["Total"]<=110),["Grade"]]="A"
df.loc[(df["Total"]>70) & (df["Total"]<=90),["Grade"]]="B+"
df.loc[(df["Total"]>50) & (df["Total"]<=70),["Grade"]]="B"
df.loc[(df["Total"]<=50),["Grade"]]="Fail"
df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 713   712    ZETA  19   8   8    19  17    18     89       74.17    B+
# 714   713    ZETA  12   1   7    10  20     8     58       48.33     B
# 715   714    ZETA  17   6  14    14  17    18     86       71.67    B+
# 716   715    ZETA  12   1   6     7  15    12     53       44.17     B
# 717   716    ZETA  19  14  17    16  20    19    105       87.50     A
#
# [716 rows x 11 columns]

# %%
failed_students_Total = df[df["Total"] < 50]
print("DataFrame of students who failed in  subjects:")
print(failed_students_Total)
# Out:
# DataFrame of students who failed in  subjects:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 20     21   ALPHA   4   2   5     3  16     9     39       32.50  Fail
# 27     28   ALPHA   5   4   3    12  13     5     42       35.00  Fail
# 57     58   ALPHA   2   2   4    10  10     3     31       25.83  Fail
# 75     76   ALPHA   5   8   7    15  10     2     47       39.17  Fail
# 82     83   ALPHA   2   0   2     0   0     0      4        3.33  Fail
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 669   668    ZETA  16   6   0     0   8     9     39       32.50  Fail
# 673   672    ZETA   2   0   0     0   2     1      5        4.17  Fail
# 679   678    ZETA  11   0   8     4   1    11     35       29.17  Fail
# 685   684    ZETA   5   1   4    15   1     6     32       26.67  Fail
# 689   688    ZETA   6   3   4     9  10    15     47       39.17  Fail
#
# [88 rows x 11 columns]

# %%
df.sort_values(["Total"], ascending=True)
# Out:
#      S.NO  SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 556   557    SIGMA   0   0   0     0   0     0      0        0.00  Fail
# 551   552    SIGMA   0   0   0     0   0     0      0        0.00  Fail
# 244   245    DELTA   0   0   0     0   0     0      0        0.00  Fail
# 402   403    GAMMA   0   0   0     0   0     0      0        0.00  Fail
# 336   337  EPSILON   0   0   0     0   0     0      0        0.00  Fail
# ..    ...      ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 251   252    DELTA  20  20  20    19  20    20    119       99.17    A+
# 505   506    OMEGA  20  20  20    20  20    20    120      100.00    A+
# 574   574    SIGMA  20  20  20    20  20    20    120      100.00    A+
# 596   596    SIGMA  20  20  20    20  20    20    120      100.00    A+
# 507   508    OMEGA  20  20  20    20  20    20    120      100.00    A+
#
# [716 rows x 11 columns]

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()

# %%
df.sort_values(["Total"], ascending=False)
# Out:
#      S.NO  SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade
# 507   508    OMEGA  20  20  20    20  20    20    120      100.00    A+
# 505   506    OMEGA  20  20  20    20  20    20    120      100.00    A+
# 574   574    SIGMA  20  20  20    20  20    20    120      100.00    A+
# 596   596    SIGMA  20  20  20    20  20    20    120      100.00    A+
# 618   617    SIGMA  20  20  20    20  20    19    119       99.17    A+
# ..    ...      ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 402   403    GAMMA   0   0   0     0   0     0      0        0.00  Fail
# 551   552    SIGMA   0   0   0     0   0     0      0        0.00  Fail
# 495   496    OMEGA   0   0   0     0   0     0      0        0.00  Fail
# 650   649     ZETA   0   0   0     0   0     0      0        0.00  Fail
# 336   337  EPSILON   0   0   0     0   0     0      0        0.00  Fail
#
# [716 rows x 11 columns]

# %%
df['Backlog_Count'] = (
    (df['DV'] < 10).astype(int) +
    (df['M2'] < 10).astype(int) +
    (df['PP'] < 10).astype(int) +
    (df['BEEE'] < 10).astype(int) +
    (df['FL'] < 10).astype(int) +
    (df['FIMS'] < 10).astype(int)
)


df
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0       1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1       2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2       3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3       4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 713   712    ZETA  19   8   8    19  17    18     89       74.17    B+
# 714   713    ZETA  12   1   7    10  20     8     58       48.33     B
# 715   714    ZETA  17   6  14    14  17    18     86       71.67    B+
# 716   715    ZETA  12   1   6     7  15    12     53       44.17     B
# 717   716    ZETA  19  14  17    16  20    19    105       87.50     A
#
#      Backlog_Count
# 0                2
# 1                1
# 2                0
# 3                1
# ...

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="PP", y="Total", data=df, marker="o")
plt.xlabel("PP")
plt.ylabel("backlog_count")
plt.title("Marks in PP comparing with backlog_count")
plt.show()

# %%
sns.relplot(data=df, x="Percentage", y="Backlog_Count")

# %% [markdown]
# # higher backlog counts are concentrared at certain percentage intervals

# %%
sns.relplot(data=df, x="PP", y="Backlog_Count")

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Backlog_Count', data=df)
plt.title('Distribution of Backlog Counts', fontsize=16)
plt.xlabel('Backlog Count', fontsize=14)
plt.ylabel('Number of Students', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # the students who got 15marks above in pp subject have the least backlogs

# %%
plt.figure(figsize=(5, 5))
sns.lineplot(x="M2", y="Total", data=df, marker="o")
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(x="M2", y="Total", data=df, marker="o")
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.boxplot(x="M2", y="Total", data=df)
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(x="M2", y="Total", data=df)
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.barplot(x="M2", y="Total", data=df)
plt.xlabel("M2")
plt.ylabel("Total")
plt.title("Marks in M2 comparing with Percentage")
plt.show()

# %%
def classify_program_skills(PP):
    if 18 <= PP <= 20:
        return "Very Good"
    elif 15 <=PP<= 17:
        return "Good"
    elif 13 <= PP <= 14:
        return "Average"
    else:
        return "Needs Improvement"  
df['Program Skills'] = df['PP'].apply(classify_program_skills)
print(df[['PP', 'Program Skills']])
# Out:
#      PP     Program Skills
# 0    17               Good
# 1    16               Good
# 2    18          Very Good
# 3    19          Very Good
# 4    19          Very Good
# ..   ..                ...
# 713   8  Needs Improvement
# 714   7  Needs Improvement
# 715  14            Average
# 716   6  Needs Improvement
# 717  17               Good
#
# [716 rows x 2 columns]

# %%
plt.figure(figsize=(5, 5))
sns.barplot(x="Program Skills", y="PP", data=df)
plt.xlabel("Program Skills")
plt.ylabel("PP")
plt.title("Program Skills comapring with PP")
plt.show()

# %%
sns.histplot(df["Program Skills"], kde=True, color="yellow")
plt.title("distribution of Program Skills")
plt.xlabel("Average skills")
plt.ylabel("frequency")
plt.show()

# %%
subset = df[df.iloc[:, 1:].eq(20).any(axis=1)]
print(subset)
# Out:
#      S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 4       5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# 6       7   ALPHA  15  10  20    20  15    14     94       78.33     A
# 7       8   ALPHA  17  17  19    20  19    13    105       87.50     A
# 8       9   ALPHA  10  18   0    20  19    15     82       68.33    B+
# 9      10   ALPHA  18  19  20    20  20    15    112       93.33    A+
# ..    ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 705   704    ZETA  16   0  11    16  20     0     63       52.50     B
# 709   708    ZETA  19  17  12    17  20    16    101       84.17     A
# 711   710    ZETA  18   9  12    20  16    16     91       75.83     A
# 714   713    ZETA  12   1   7    10  20     8     58       48.33     B
# 717   716    ZETA  19  14  17    16  20    19    105       87.50     A
#
#      Backlog_Count     Program Skills
# 4                0          Very Good
# ...

# %%
df.value_counts()
# Out:
# S.NO  SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage  Grade  Backlog_Count  Program Skills
# 1     ALPHA    12  0   17  9     19  15    72     60.00       B+     2              Good                 1
# 493   OMEGA    20  4   16  19    20  16    95     79.17       A      1              Good                 1
# 473   OMEGA    15  7   10  5     8   10    55     45.83       B      3              Needs Improvement    1
# 474   OMEGA    20  16  20  20    20  18    114    95.00       A+     0              Very Good            1
# 475   OMEGA    20  18  20  19    20  18    115    95.83       A+     0              Very Good            1
#                                                                                                         ..
# 241   DELTA    6   6   2   3     10  11    38     31.67       Fail   4              Needs Improvement    1
# 242   DELTA    15  1   18  18    20  19    91     75.83       A      1              Very Good            1
# ...

# %%
df.describe()
# Out:
#              S.NO          DV          M2          PP        BEEE          FL  \
# count  716.000000  716.000000  716.000000  716.000000  716.000000  716.000000
# mean   358.500000   14.784916    9.949721   12.766760   13.287709   15.544693
# std    206.835684    4.579198    6.599236    5.823998    5.783112    4.476132
# min      1.000000   -2.000000    0.000000   -2.000000    0.000000    0.000000
# 25%    179.750000   12.000000    4.000000    9.000000    9.000000   13.000000
# 50%    358.500000   16.000000   10.000000   14.000000   15.000000   16.000000
# 75%    537.250000   18.000000   16.000000   18.000000   18.000000   20.000000
# max    716.000000   20.000000   20.000000   20.000000   20.000000   20.000000
#
#              FIMS       Total  Percentage  Backlog_Count
# count  716.000000  716.000000  716.000000     716.000000
# mean    14.047486   80.381285   66.984288       1.393855
# std      4.709815   25.335978   21.113396       1.536927
# ...

# %%
print(df.describe(include='all'))
# Out:
#               S.NO SECTION          DV          M2          PP        BEEE  \
# count   716.000000     716  716.000000  716.000000  716.000000  716.000000
# unique         NaN       8         NaN         NaN         NaN         NaN
# top            NaN   ALPHA         NaN         NaN         NaN         NaN
# freq           NaN      90         NaN         NaN         NaN         NaN
# mean    358.500000     NaN   14.784916    9.949721   12.766760   13.287709
# std     206.835684     NaN    4.579198    6.599236    5.823998    5.783112
# min       1.000000     NaN   -2.000000    0.000000   -2.000000    0.000000
# 25%     179.750000     NaN   12.000000    4.000000    9.000000    9.000000
# 50%     358.500000     NaN   16.000000   10.000000   14.000000   15.000000
# 75%     537.250000     NaN   18.000000   16.000000   18.000000   18.000000
# max     716.000000     NaN   20.000000   20.000000   20.000000   20.000000
#
# ...

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA') 
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
df
# Out:
# C:\Users\DELL-PC\AppData\Local\Temp\ipykernel_15272\1840477511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SECTION'] = df['SECTION'].fillna('SIGMA')
# C:\Users\DELL-PC\AppData\Local\Temp\ipykernel_15272\1840477511.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
#     S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0      1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# ...

# %%
PS= df['Program Skills'].value_counts()
plt.figure(figsize=(8, 8))
PS.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['red', 'blue', 'green', 'orange', 'purple', 'cyan'])
plt.title('Programming Skills distribution')

plt.show()

# %%
backlog_distribution = df['Backlog_Count'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(
    backlog_distribution, 
    labels=backlog_distribution.index, 
    autopct='%1.1f%%', 
    startangle=90, 
    colors=sns.color_palette('Set2', len(backlog_distribution))
)
plt.title('Distribution of Backlog Counts', fontsize=16)
plt.show()

# %%
def classify_Analytical_Skills(PP):
    if 18 <= PP <= 20:
        return "Very Good"
    elif 15 <=PP<= 17:
        return "Good"
    elif 13 <= PP <= 14:
        return "Average"
    else:
        return "Needs Improvement"  
df['Analytical Skills'] = df['PP'].apply(classify_Analytical_Skills)
print(df[['PP', 'Analytical Skills']])

# %%
AS= df['Analytical Skills'].value_counts()
plt.figure(figsize=(8, 8))
PS.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['violet', 'pink', 'green', 'red', 'purple', 'cyan'])
plt.title('Analytical Skills distribution')

plt.show()

# %%
pass_mark = 10  


df['DV Result'] = df['DV'].apply(lambda x: 'Pass' if x >= pass_mark else 'Fail')

pass_fail_counts = df['DV Result'].value_counts()


print(pass_fail_counts)
# Out:
# DV Result
# Pass    629
# Fail     87
# Name: count, dtype: int64

# %%
passing_mark = 10
alpha_section = df[df['SECTION'] == 'ALPHA'].copy()  
alpha_section.loc[:, 'M2'] = pd.to_numeric(alpha_section['M2'], errors='coerce')
alpha_section.loc[:, 'M2 Result'] = alpha_section['M2'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
alpha_mii_pass_fail_counts = alpha_section['M2 Result'].value_counts()
print("--- ALPHA Section: M-II Pass/Fail Counts ---")
print(alpha_mii_pass_fail_counts)
# Out:
# --- ALPHA Section: M-II Pass/Fail Counts ---
# M2 Result
# Pass    72
# Fail    18
# Name: count, dtype: int64

# %%
passing_mark = 10
delta_section = df[df['SECTION'] == 'DELTA'].copy()  
delta_section.loc[:, 'M2'] = pd.to_numeric(delta_section['M2'], errors='coerce')
delta_section.loc[:, 'M2 Result'] = delta_section['M2'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
delta_mii_pass_fail_counts = delta_section['M2 Result'].value_counts()
print("--- DELTA Section: M2 Pass/Fail Counts ---")
print(delta_mii_pass_fail_counts)
# Out:
# --- DELTA Section: M2 Pass/Fail Counts ---
# M2 Result
# Pass    45
# Fail    45
# Name: count, dtype: int64

# %%
passing_mark = 10
gamma_section = df[df['SECTION'] == 'GAMMA'].copy()  
gamma_section.loc[:, 'M2'] = pd.to_numeric(gamma_section['M2'], errors='coerce')
gamma_section.loc[:, 'M2 Result'] = gamma_section['M2'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
gamma_mii_pass_fail_counts = gamma_section['M2 Result'].value_counts()
print("--- GAMMA Section: M2 Pass/Fail Counts ---")
print(alpha_mii_pass_fail_counts)
# Out:
# --- GAMMA Section: M2 Pass/Fail Counts ---
# M2 Result
# Pass    72
# Fail    18
# Name: count, dtype: int64

# %%
passing_mark = 10
gamma_section = df[df['SECTION'] == 'GAMMA'].copy()
gamma_section.loc[:, 'DV'] = pd.to_numeric(gamma_section['DV'], errors='coerce')
gamma_section.loc[:, 'DV Result'] = gamma_section['DV'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
gamma_mii_pass_fail_counts = gamma_section['DV Result'].value_counts()
gamma_mii_pass_fail_percentages = (gamma_mii_pass_fail_counts / gamma_mii_pass_fail_counts.sum()) * 100
print("\n--- GAMMA Section: DV Pass/Fail Percentages ---")
print(gamma_mii_pass_fail_percentages)
# Out:
# --- GAMMA Section: DV Pass/Fail Percentages ---
# DV Result
# Pass    87.777778
# Fail    12.222222
# Name: count, dtype: float64

# %%
passing_mark = 10
gamma_section = df[df['SECTION'] == 'GAMMA'].copy()
gamma_section.loc[:, 'BEEE'] = pd.to_numeric(gamma_section['BEEE'], errors='coerce')
gamma_section.loc[:, 'BEEE Result'] = gamma_section['BEEE'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
gamma_mii_pass_fail_counts = gamma_section['BEEE Result'].value_counts()
gamma_mii_pass_fail_percentages = (gamma_mii_pass_fail_counts / gamma_mii_pass_fail_counts.sum()) * 100
print("\n--- GAMMA Section: BEEE Pass/Fail Percentages ---")
print(gamma_mii_pass_fail_percentages)
# Out:
# --- GAMMA Section: BEEE Pass/Fail Percentages ---
# BEEE Result
# Pass    81.111111
# Fail    18.888889
# Name: count, dtype: float64

# %%
passing_mark = 10
gamma_section = df[df['SECTION'] == 'GAMMA'].copy()
gamma_section.loc[:, 'FL'] = pd.to_numeric(gamma_section['FL'], errors='coerce')
gamma_section.loc[:, 'FL Result'] = gamma_section['FL'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
gamma_mii_pass_fail_counts = gamma_section['FL Result'].value_counts()
gamma_mii_pass_fail_percentages = (gamma_mii_pass_fail_counts / gamma_mii_pass_fail_counts.sum()) * 100
print("\n--- GAMMA Section: FL Pass/Fail Percentages ---")
print(gamma_mii_pass_fail_percentages)
# Out:
# --- GAMMA Section: FL Pass/Fail Percentages ---
# FL Result
# Pass    97.777778
# Fail     2.222222
# Name: count, dtype: float64

# %%
passing_mark = 10
gamma_section = df[df['SECTION'] == 'GAMMA'].copy()
gamma_section.loc[:, 'PP'] = pd.to_numeric(gamma_section['PP'], errors='coerce')
gamma_section.loc[:, 'PP Result'] = gamma_section['PP'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
gamma_mii_pass_fail_counts = gamma_section['PP Result'].value_counts()
gamma_mii_pass_fail_percentages = (gamma_mii_pass_fail_counts / gamma_mii_pass_fail_counts.sum()) * 100
print("\n--- GAMMA Section: PP Pass/Fail Percentages ---")
print(gamma_mii_pass_fail_percentages)
# Out:
# --- GAMMA Section: PP Pass/Fail Percentages ---
# PP Result
# Pass    60.0
# Fail    40.0
# Name: count, dtype: float64

# %%
passing_mark = 10
gamma_section = df[df['SECTION'] == 'GAMMA'].copy()
gamma_section.loc[:, 'FIMS'] = pd.to_numeric(gamma_section['FIMS'], errors='coerce')
gamma_section.loc[:, 'FIMS Result'] = gamma_section['FIMS'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
gamma_mii_pass_fail_counts = gamma_section['FIMS Result'].value_counts()
gamma_mii_pass_fail_percentages = (gamma_mii_pass_fail_counts / gamma_mii_pass_fail_counts.sum()) * 100
print("\n--- GAMMA Section: FIMS Pass/Fail Percentages ---")
print(gamma_mii_pass_fail_percentages)
# Out:
# --- GAMMA Section: FIMS Pass/Fail Percentages ---
# FIMS Result
# Pass    74.444444
# Fail    25.555556
# Name: count, dtype: float64

# %%
passing_mark = 10
delta_section = df[df['SECTION'] == 'DELTA'].copy()  
delta_section.loc[:, 'FIMS'] = pd.to_numeric(delta_section['FIMS'], errors='coerce')
delta_section.loc[:, 'FIMS Result'] = delta_section['FIMS'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
delta_mii_pass_fail_counts = delta_section['FIMS Result'].value_counts()
delta_mii_pass_fail_percentages = (delta_mii_pass_fail_counts / delta_mii_pass_fail_counts.sum()) * 100
print("\n--- DELTA Section: FIMS Pass/Fail Percentages ---")
print(delta_mii_pass_fail_percentages)
# Out:
# --- DELTA Section: FIMS Pass/Fail Percentages ---
# FIMS Result
# Pass    95.555556
# Fail     4.444444
# Name: count, dtype: float64

# %%
passing_mark = 10
delta_section = df[df['SECTION'] == 'DELTA'].copy()  
delta_section.loc[:, 'PP'] = pd.to_numeric(delta_section['PP'], errors='coerce')
delta_section.loc[:, 'PP Result'] = delta_section['PP'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
delta_mii_pass_fail_counts = delta_section['PP Result'].value_counts()
delta_mii_pass_fail_percentages = (delta_mii_pass_fail_counts / delta_mii_pass_fail_counts.sum()) * 100
print("\n--- DELTA Section: PP Pass/Fail Percentages ---")
print(delta_mii_pass_fail_percentages)
# Out:
# --- DELTA Section: PP Pass/Fail Percentages ---
# PP Result
# Pass    68.888889
# Fail    31.111111
# Name: count, dtype: float64

# %%
passing_mark = 10
delta_section = df[df['SECTION'] == 'DELTA'].copy()  
delta_section.loc[:, 'FL'] = pd.to_numeric(delta_section['FL'], errors='coerce')
delta_section.loc[:, 'FL Result'] = delta_section['FL'].apply(lambda x: 'Pass' if x >= passing_mark else 'Fail')
delta_mii_pass_fail_counts = delta_section['FL Result'].value_counts()
delta_mii_pass_fail_percentages = (delta_mii_pass_fail_counts / delta_mii_pass_fail_counts.sum()) * 100
print("\n--- DELTA Section: FL Pass/Fail Percentages ---")
print(delta_mii_pass_fail_percentages)
# Out:
# --- DELTA Section: FL Pass/Fail Percentages ---
# FL Result
# Pass    98.888889
# Fail     1.111111
# Name: count, dtype: float64

# %%
df[df["SECTION"]=="ALPHA"].mean
# Out:
# <bound method DataFrame.mean of     S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0      1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1      2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2      3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3      4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4      5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..   ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 85    86   ALPHA   3   4  14    13  18    13     65       54.17     B
# 86    87   ALPHA  17  18  19    20  20    18    112       93.33    A+
# 87    88   ALPHA  13  17  14    19  15    17     95       79.17     A
# 88    89   ALPHA   2  17   0     3  15     2     39       32.50  Fail
# 89    90   ALPHA  10   6  15    10  15    10     66       55.00     B
#
#     Backlog_Count     Program Skills  status DV Result
# ...

# %%
df["DV"].mean()
# Out:
# 14.78491620111732

# %%
df=df[df["SECTION"]=="ALPHA"]
df["DV"].mean()
# Out:
# 13.411111111111111

# %%
df.shape
# Out:
# (90, 15)

# %%
df.info
# Out:
# <bound method DataFrame.info of     S.NO SECTION  DV  M2  PP  BEEE  FL  FIMS  Total  Percentage Grade  \
# 0      1   ALPHA  12   0  17     9  19    15     72       60.00    B+
# 1      2   ALPHA  19  12  16    16  18     3     84       70.00    B+
# 2      3   ALPHA  18  14  18    18  18    16    102       85.00     A
# 3      4   ALPHA  15   9  19    17  19    15     94       78.33     A
# 4      5   ALPHA  18  17  19    19  20    18    111       92.50    A+
# ..   ...     ...  ..  ..  ..   ...  ..   ...    ...         ...   ...
# 85    86   ALPHA   3   4  14    13  18    13     65       54.17     B
# 86    87   ALPHA  17  18  19    20  20    18    112       93.33    A+
# 87    88   ALPHA  13  17  14    19  15    17     95       79.17     A
# 88    89   ALPHA   2  17   0     3  15     2     39       32.50  Fail
# 89    90   ALPHA  10   6  15    10  15    10     66       55.00     B
#
#     Backlog_Count     Program Skills  status DV Result
# ...

# %%
df.shape
# Out:
# (90, 15)

# %%
df.shape
# Out:
# (90, 15)

# %% [markdown]
# The dataset was thoroughly explored, providing a detailed understanding of its structure, numerical distributions, and relationships between variables.
#
# Visualizations such as box plots, histograms, and scatter plots highlighted key trends, outliers, and data distributions.

# %% [markdown]
# The visualizations and analysis revealed meaningful patterns, such as correlations between variables or specific trends over time.
#
# Categories like teacher-student ratios or other metrics in the dataset were effectively categorized and analyzed.
